# %% [markdown]
# <a href="https://colab.research.google.com/github/vichu2k7-crypto/DBMS/blob/main/DBMS_Lab_Experiment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

# Connect to Database
conn = sqlite3.connect("college.db")
cursor = conn.cursor()

print("Database Connected Successfully")

# Create Student Table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Student(
    RollNo INTEGER PRIMARY KEY,
    Name TEXT,
    Age INTEGER,
    Department TEXT
)
""")

print("Table Created Successfully")

# Insert Sample Records
cursor.execute("INSERT OR IGNORE INTO Student VALUES(101,'Rahul',19,'CSE')")
cursor.execute("INSERT OR IGNORE INTO Student VALUES(102,'Priya',20,'ECE')")
cursor.execute("INSERT OR IGNORE INTO Student VALUES(103,'Arun',18,'IT')")

conn.commit()

print("\nRecords Before Update:")
cursor.execute("SELECT * FROM Student")
rows = cursor.fetchall()
for row in rows:
    print(row)

# Update Record
cursor.execute("""
UPDATE Student
SET Department='AIML'
WHERE RollNo=101
""")

conn.commit()

print("\nRecords After Update:")
cursor.execute("SELECT * FROM Student")
rows = cursor.fetchall()
for row in rows:
    print(row)

# Delete Record
cursor.execute("""
DELETE FROM Student
WHERE RollNo=103
""")

conn.commit()

print("\nRecords After Delete:")
cursor.execute("SELECT * FROM Student")
rows = cursor.fetchall()
for row in rows:
    print(row)

# Close Database
conn.close()

print("\nDatabase Closed Successfully")
# Out:
# Database Connected Successfully
# Table Created Successfully
#
# Records Before Update:
# (101, 'Rahul', 19, 'CSE')
# (102, 'Priya', 20, 'ECE')
# (103, 'Arun', 18, 'IT')
#
# Records After Update:
# (101, 'Rahul', 19, 'AIML')
# (102, 'Priya', 20, 'ECE')
# (103, 'Arun', 18, 'IT')
#
# Records After Delete:
# (101, 'Rahul', 19, 'AIML')
# (102, 'Priya', 20, 'ECE')
#
# Database Closed Successfully
