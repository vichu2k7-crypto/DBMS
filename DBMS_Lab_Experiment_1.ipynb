# %% [markdown]
# <a href="https://colab.research.google.com/github/vichu2k7-crypto/DBMS/blob/main/DBMS_Lab_Experiment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

conn = sqlite3.connect("college.db")
cursor = conn.cursor()

print("Database Connected Successfully")
cursor.execute("""
CREATE TABLE Student(
RollNo INTEGER PRIMARY KEY,
Name TEXT,
Age INTEGER
)
""")

print("Table Created")
cursor.execute("SELECT * FROM Student")
print(cursor.fetchall())
cursor.execute("ALTER TABLE Student ADD COLUMN Department TEXT")
print("Column Added")
cursor.execute("DELETE FROM Student")
conn.commit()

print("All Records Deleted")
cursor.execute("DROP TABLE Student")
print("Table Deleted")
conn.commit()
conn.close()
# Out:
# Database Connected Successfully
# Table Created
# []
# Column Added
# All Records Deleted
# Table Deleted
